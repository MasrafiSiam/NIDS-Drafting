# %%
import pandas as pd

# %%
df = pd.read_csv("output.csv")

df.head(67)
# Out:
#              src_ip           dst_ip  src_port  dst_port  protocol  \
# 0     192.168.0.195   57.144.142.145     57402       443         6
# 1     35.186.224.24    192.168.0.195       443     52350        17
# 2    57.144.143.134    192.168.0.195       443     62573         6
# 3   162.159.130.234    192.168.0.195       443     61113         6
# 4     35.186.224.22    192.168.0.195       443     64907        17
# 5     192.168.0.195      192.168.0.1     50506        53        17
# 6     192.168.0.195   57.144.142.145     64907       443         6
# 7     192.168.0.195     57.144.140.1     52359       443        17
# 8     192.168.0.195  192.178.158.113     57416       443         6
# 9     35.186.224.24    192.168.0.195       443     58239         6
# 10    192.168.0.195    175.6.233.195     51170       443         6
# 11    192.168.0.195  199.232.210.250     54045       443         6
# 12    192.168.0.195   142.250.118.95     50879       443         6
# ...

# %%
with open("columns.txt", "w") as f:
    for col in df.columns:
        f.write(col + "\n")
